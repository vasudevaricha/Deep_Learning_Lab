# %% [markdown]
# need of neural network :
#
# 1.   learn complex patterns
# 2.   Mimic human brain
#
# Neural network is satck of layers
#
# *   input layer
# *   one or more hidden layers
# *   Output layer

# %% [markdown]
# **Tensor flow**
# Deeep learning framework that is used to perform **tensor operations.** i.e. training,loops and gradients.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# %%
# 1. Generate a 2D binary classification dataset
X, y = make_classification(n_samples=500, n_features=2, n_informative=2, n_redundant=0,
                           n_clusters_per_class=1, random_state=42)

# 2. Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# 4. Define a simple neural network model in Keras
model = tf.keras.Sequential([
    # 10 here is no of neurons
    tf.keras.layers.Dense(10, activation='relu', input_shape=(2,)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
# tf.keras.sequential is used to make any neural network.
# under this we can give layer
# 5. Compile the model
# in compilaion we use optimiser, loss function and

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# 6. Train the model and capture training history
# we train the model in batches and thus we have to
history = model.fit(X_train, y_train, epochs=30, batch_size=16, validation_split=0.2)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.5112 - loss: 0.8533 - val_accuracy: 0.5375 - val_loss: 0.8260
# Epoch 2/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4825 - loss: 0.8581 - val_accuracy: 0.5375 - val_loss: 0.7827
# Epoch 3/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4988 - loss: 0.7825 - val_accuracy: 0.5375 - val_loss: 0.7482
# Epoch 4/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5260 - loss: 0.7504 - val_accuracy: 0.5625 - val_loss: 0.7166
# Epoch 5/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5529 - loss: 0.7173 - val_accuracy: 0.5750 - val_loss: 0.6878
# Epoch 6/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5408 - loss: 0.7058 - val_accuracy: 0.5875 - val_loss: 0.6631
# Epoch 7/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6007 - loss: 0.6656 - val_accuracy: 0.7250 - val_loss: 0.6406
# Epoch 8/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6731 - loss: 0.6504 - val_accuracy: 0.7875 - val_loss: 0.6194
# Epoch 9/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7830 - loss: 0.6238 - val_accuracy: 0.8500 - val_loss: 0.6001
# Epoch 10/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7471 - loss: 0.6089 - val_accuracy: 0.8500 - val_loss: 0.5823
# Epoch 11/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8234 - loss: 0.5865 - val_accuracy: 0.8500 - val_loss: 0.5644
# Epoch 12/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7680 - loss: 0.5807 - val_accuracy: 0.8750 - val_loss: 0.5480
# Epoch 13/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8543 - loss: 0.5334 - val_accuracy: 0.8750 - val_loss: 0.5309
# Epoch 14/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8284 - loss: 0.5335 - val_accuracy: 0.8750 - val_loss: 0.5161
# Epoch 15/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7936 - loss: 0.5278 - val_accuracy: 0.8750 - val_loss: 0.5019
# Epoch 16/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8274 - loss: 0.5106 - val_accuracy: 0.8625 - val_loss: 0.4876
# Epoch 17/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8219 - loss: 0.4964 - val_accuracy: 0.8625 - val_loss: 0.4746
# Epoch 18/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8764 - loss: 0.4695 - val_accuracy: 0.8750 - val_loss: 0.4610
# Epoch 19/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8234 - loss: 0.4703 - val_accuracy: 0.8875 - val_loss: 0.4492
# Epoch 20/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8415 - loss: 0.4666 - val_accuracy: 0.8875 - val_loss: 0.4374
# Epoch 21/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8690 - loss: 0.4307 - val_accuracy: 0.8875 - val_loss: 0.4260
# Epoch 22/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8448 - loss: 0.4338 - val_accuracy: 0.9125 - val_loss: 0.4150
# Epoch 23/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8485 - loss: 0.4167 - val_accuracy: 0.9125 - val_loss: 0.4052
# Epoch 24/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8948 - loss: 0.3941 - val_accuracy: 0.9125 - val_loss: 0.3956
# Epoch 25/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8610 - loss: 0.4201 - val_accuracy: 0.9250 - val_loss: 0.3866
# Epoch 26/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8956 - loss: 0.3838 - val_accuracy: 0.9250 - val_loss: 0.3776
# Epoch 27/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8876 - loss: 0.3826 - val_accuracy: 0.9250 - val_loss: 0.3700
# Epoch 28/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8894 - loss: 0.3737 - val_accuracy: 0.9250 - val_loss: 0.3623
# Epoch 29/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8711 - loss: 0.3676 - val_accuracy: 0.9250 - val_loss: 0.3549
# Epoch 30/30
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8759 - loss: 0.3712 - val_accuracy: 0.9125 - val_loss: 0.3482

# %%
# 7. Plot the dataset
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=y, cmap='bwr', edgecolors='k', alpha=0.7)
plt.title("2D Binary Classification Dataset")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.grid(True)

# 8. Plot accuracy over epochs
# .subplot(a,b,c) means = subplot(ist row)
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy vs Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# implementation using pytorch

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score

# %%
# 1. Generate dataset
X, y = make_classification(n_samples=500, n_features=2, n_redundant=0,
                           n_informative=2, n_clusters_per_class=1, random_state=42)

# 2. Scale and split (train and test)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# 3. Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.reshape(-1, 1), dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test.reshape(-1, 1), dtype=torch.float32)

# %%
# 4. Visualize dataset
plt.figure(figsize=(6, 5))
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=y, cmap='bwr', edgecolors='k')
plt.title("2D Binary Classification Dataset")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# 5. Define the model
# nn denotes neural network
# super function is special class function to define
class SimpleNN(nn.Module):
    def __init__(self, input_dim):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(input_dim, 10)
        self.fc2 = nn.Linear(10, 1)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = torch.sigmoid(self.fc2(x))
        return x

# %%
model = SimpleNN(input_dim=2)
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
# 6. Train the model
num_epochs = 30
train_accuracies = []
test_accuracies = []
losses = []

for epoch in range(num_epochs):
    model.train()

    outputs = model(X_train_tensor)
    loss = criterion(outputs, y_train_tensor)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    model.eval()
    with torch.no_grad():
        # Training accuracy
        train_preds = (outputs >= 0.5).float()
        train_acc = accuracy_score(y_train_tensor.numpy(), train_preds.numpy())

        # Test accuracy
        test_outputs = model(X_test_tensor)
        test_preds = (test_outputs >= 0.5).float()
        test_acc = accuracy_score(y_test_tensor.numpy(), test_preds.numpy())

    train_accuracies.append(train_acc)
    test_accuracies.append(test_acc)
    losses.append(loss.item())

    print(f"Epoch {epoch+1}/{num_epochs} - Loss: {loss.item():.4f} - Train Acc: {train_acc:.4f} - Test Acc: {test_acc:.4f}")
# Out:
# Epoch 1/30 - Loss: 0.6915 - Train Acc: 0.4900 - Test Acc: 0.5600
# Epoch 2/30 - Loss: 0.6799 - Train Acc: 0.5425 - Test Acc: 0.6200
# Epoch 3/30 - Loss: 0.6686 - Train Acc: 0.6225 - Test Acc: 0.6900
# Epoch 4/30 - Loss: 0.6575 - Train Acc: 0.6775 - Test Acc: 0.7300
# Epoch 5/30 - Loss: 0.6467 - Train Acc: 0.7175 - Test Acc: 0.7400
# Epoch 6/30 - Loss: 0.6362 - Train Acc: 0.7325 - Test Acc: 0.8100
# Epoch 7/30 - Loss: 0.6259 - Train Acc: 0.7625 - Test Acc: 0.8200
# Epoch 8/30 - Loss: 0.6157 - Train Acc: 0.8025 - Test Acc: 0.8400
# Epoch 9/30 - Loss: 0.6055 - Train Acc: 0.8200 - Test Acc: 0.8500
# Epoch 10/30 - Loss: 0.5955 - Train Acc: 0.8275 - Test Acc: 0.8300
# Epoch 11/30 - Loss: 0.5855 - Train Acc: 0.8250 - Test Acc: 0.8400
# Epoch 12/30 - Loss: 0.5756 - Train Acc: 0.8275 - Test Acc: 0.8500
# Epoch 13/30 - Loss: 0.5657 - Train Acc: 0.8350 - Test Acc: 0.8700
# Epoch 14/30 - Loss: 0.5559 - Train Acc: 0.8350 - Test Acc: 0.8700
# Epoch 15/30 - Loss: 0.5461 - Train Acc: 0.8400 - Test Acc: 0.8700
# Epoch 16/30 - Loss: 0.5364 - Train Acc: 0.8425 - Test Acc: 0.8800
# Epoch 17/30 - Loss: 0.5266 - Train Acc: 0.8450 - Test Acc: 0.8800
# Epoch 18/30 - Loss: 0.5169 - Train Acc: 0.8500 - Test Acc: 0.8800
# Epoch 19/30 - Loss: 0.5072 - Train Acc: 0.8600 - Test Acc: 0.8800
# Epoch 20/30 - Loss: 0.4976 - Train Acc: 0.8600 - Test Acc: 0.8800
# Epoch 21/30 - Loss: 0.4880 - Train Acc: 0.8600 - Test Acc: 0.8800
# Epoch 22/30 - Loss: 0.4785 - Train Acc: 0.8650 - Test Acc: 0.8800
# Epoch 23/30 - Loss: 0.4691 - Train Acc: 0.8675 - Test Acc: 0.8800
# Epoch 24/30 - Loss: 0.4597 - Train Acc: 0.8700 - Test Acc: 0.8800
# Epoch 25/30 - Loss: 0.4505 - Train Acc: 0.8675 - Test Acc: 0.8800
# Epoch 26/30 - Loss: 0.4415 - Train Acc: 0.8700 - Test Acc: 0.8800
# Epoch 27/30 - Loss: 0.4327 - Train Acc: 0.8675 - Test Acc: 0.8800
# Epoch 28/30 - Loss: 0.4240 - Train Acc: 0.8675 - Test Acc: 0.8800
# Epoch 29/30 - Loss: 0.4155 - Train Acc: 0.8700 - Test Acc: 0.8800
# Epoch 30/30 - Loss: 0.4073 - Train Acc: 0.8725 - Test Acc: 0.8800

# %%
# 7. Plot loss and combined accuracy
plt.figure(figsize=(12, 5))

# Loss Plot
plt.subplot(1, 2, 1)
plt.plot(losses, label="Loss", color='red')
plt.title("Training Loss Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)

# Combined Accuracy Plot
plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label="Train Accuracy", color='green')
plt.plot(test_accuracies, label="Test Accuracy", color='orange')
plt.title("Train vs Test Accuracy Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Teserflow:
#
# 1) Create a tensor, print it, define a simple model adn print its summary
# 2) Generate a random tensor and(3x3),print it and perform matrix multiplication and print the result.
# 3) Create two tensors and perform element wise addition
#
# 4) In Keras Define a two layer sequential model,complile it and run for 30 epochs, and print the predicted results.
# x1=[1,2,3,4]
# y1=[2,4,5,6]

# %% [markdown]
# **1) Create a tensor, print it, define a simple model adn print its summary**

# %%
import tensorflow as tf

# 1. Create a tensor and print it
my_tensor = tf.constant([[1, 2, 3], [4, 5, 6]], dtype=tf.float32)
print("Created Tensor:")
print(my_tensor.numpy())
print("\n")

# 2. Define a simple TensorFlow Keras model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(3,)), # Input layer with 3 features
    tf.keras.layers.Dense(1, activation='sigmoid') # Output layer
])

# 3. Print the model summary
print("Model Summary:")
model.summary()
# Out:
# Created Tensor:
# [[1. 2. 3.]
#  [4. 5. 6.]]
#
#
# Model Summary:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 10)             │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 51 (204.00 B)
#  Trainable params: 51 (204.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **2) Generate a random tensor and(3x3),print it and perform matrix multiplication and print the result.**

# %%
import tensorflow as tf

# 1. Generate a random 3x3 tensor
tensor_a = tf.random.normal(shape=(3, 3))
print("Tensor A (3x3):")
print(tensor_a.numpy())
print("\n")

# Generate another random tensor for multiplication (e.g., 3x2)
tensor_b = tf.random.normal(shape=(3, 2))
print("Tensor B (3x3):")
print(tensor_b.numpy())
print("\n")
result_tensor = tf.matmul(tensor_a, tensor_b)

# 3. Print the result
print("Result of Matrix Multiplication (A @ B):")
print(result_tensor.numpy())
# Out:
# Tensor A (3x3):
# [[-1.102423   -0.7645128  -1.4530576 ]
#  [-1.3277808   0.3350705  -0.611695  ]
#  [-0.88868773  1.710988    0.51864374]]
#
#
# Tensor B (3x3):
# [[ 1.2707303   1.639082  ]
#  [-1.4729081  -0.14501387]
#  [-0.44335714 -0.21984115]]
#
#
# Result of Matrix Multiplication (A @ B):
# [[ 0.3693984 -1.3766546]
#  [-1.9095801 -2.0904558]
#  [-3.8793552 -1.8187683]]

# %% [markdown]
# **3) Create two tensors and perform element wise addition**

# %%
import tensorflow as tf

# Create two tensors
tensor1 = tf.constant([1, 2], dtype=tf.float32)
tensor2 = tf.constant([5, 6], dtype=tf.float32)

print("Tensor 1:")
print(tensor1.numpy())
print("\nTensor 2:")
print(tensor2.numpy())

# Perform element-wise addition
result_addition = tf.add(tensor1, tensor2)

print("\nResult of Element-wise Addition:")
print(result_addition.numpy())
# Out:
# Tensor 1:
# [1. 2.]
#
# Tensor 2:
# [5. 6.]
#
# Result of Element-wise Addition:
# [6. 8.]

# %% [markdown]
# # Keras
# 1) In Keras Define a two layer sequential model,complile it and run for 30 epochs, and print the predicted results. given y=2x
# x1=[1,2,3,4]
# y1=[2,4,5,6]

# %%
import tensorflow as tf
import numpy as np

# Input data
x1 = np.array([1, 2, 3, 4], dtype=float)
y1 = np.array([2, 4, 5, 6], dtype=float)

# Reshape data for Keras (from (n,) to (n, 1))
x_train = x1.reshape(-1, 1)
y_train = y1.reshape(-1, 1)

# Define a two-layer sequential model
model_keras = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(1,)), # First hidden layer
    tf.keras.layers.Dense(1) # Output layer for regression (no activation for linear output)
])

# Compile the model
model_keras.compile(optimizer='adam', loss='mse') # Using Mean Squared Error for regression

# Train the model
history_keras = model_keras.fit(x_train, y_train, epochs=30, verbose=0)
print("Model training complete.\n")

# Predict results
predictions = model_keras.predict(x_train)

# Print the predicted results
print("Predicted results:")
for i in range(len(x1)):
    print(f"Input: {x1[i]}, Actual: {y1[i]}, Predicted: {predictions[i][0]:.2f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model training complete.
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Predicted results:
# Input: 1.0, Actual: 2.0, Predicted: 0.46
# Input: 2.0, Actual: 4.0, Predicted: 0.85
# Input: 3.0, Actual: 5.0, Predicted: 1.24
# Input: 4.0, Actual: 6.0, Predicted: 1.62

# %% [markdown]
# # PyTorch
# 1) Create a tensor, print it, then generate a random(2x2) tensor, tensor (3x3) , perform element wise addition adn print result.
# 2) Define a simple neural network and print its structure

# %% [markdown]
# 1) a. Design a single unit perceptron for classification of linearly seperable binary data set without using predefined models.
# b. Identify problem with single layer perceptron. Classify usin OR and XOR AND analyse the result.
# ( single unit perceptron is basic ANN for classification)
#
# Single neuron is known as unit
